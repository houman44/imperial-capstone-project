# %% [markdown]
# <a href="https://colab.research.google.com/github/houman44/imperial-capstone-project/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.filterwarnings("ignore", message="Predicted variances smaller than 0. Setting those variances to 0.")
from sklearn.exceptions import ConvergenceWarning

warnings.filterwarnings("ignore", category=ConvergenceWarning)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF,RationalQuadratic, Matern
import matplotlib.pyplot as plt


import sklearn

# %%
print(sklearn.__version__)
# Out:
# 1.6.1

# %%
from sklearn.gaussian_process.kernels import Matern, WhiteKernel
np.random.seed(234) #Do not change the random seed
x = np.random.uniform(0, 10, (10, 1))

def true_function(x):
    return -(1.4 - 3.0 * x) * np.sin(x)

y = true_function(x)

y = y.ravel()  #Convert to 1D

#kernel = 1.0 * RationalQuadratic(length_scale=2.0)
kernel = 1.0 * Matern(length_scale=1.0, nu=2.5) + WhiteKernel(noise_level=0.1)
gpr = GaussianProcessRegressor(kernel=kernel, n_restarts_optimizer=9)
gpr.fit(x, y)
# Out:
# GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=0.1),
#                          n_restarts_optimizer=9)

# %%
import matplotlib.pyplot as plt

#Create test points
x_test = np.linspace(0, 10, 100).reshape(-1, 1)
y_pred, std = gpr.predict(x_test, return_std=True)

#Plot
plt.figure(figsize=(10, 5))
plt.plot(x_test, true_function(x_test), 'r:', label='True function')
plt.scatter(x, y, c='k', label='Observations')
plt.plot(x_test, y_pred, 'b-', label='Mean prediction')
plt.fill_between(x_test.ravel(),
                 y_pred - 1.00 * std, # Changed 1.96 to 1.00
                 y_pred + 1.00 * std, # Changed 1.96 to 1.00
                 alpha=0.2, color='blue', label='68% confidence interval')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.title('Gaussian Process Regression with Your Dataset')
plt.show()

# %%
import matplotlib.pyplot as plt
from scipy.stats import norm

#Create test points
x_test = np.linspace(0, 10, 100).reshape(-1, 1)
y_pred, std = gpr.predict(x_test, return_std=True)

confidence_levels = {
    "68%": 0.68,
    "90%": 0.90,
    "99%": 0.99
}

ci_factors = {}
for name, level in confidence_levels.items():
    # Calculate the Z-score for the two-sided confidence interval
    ci_factors[name] = norm.ppf((1 + level) / 2)

# Plotting setup
plt.figure(figsize=(10, 6))
plt.scatter(x, y, color='red', marker='x', label='Training Data')
plt.plot(x_test, y_pred_pred, color='black', label='GP Mean Prediction')

colors = ['#C8E6C9', '#A5D6A7', '#81C784'] # Light to Dark Green
# Sort levels to plot widest (99%) first, so it appears as the background
sorted_levels = sorted(confidence_levels.items(), key=lambda item: item[1], reverse=True)

for (name, level), color in zip(sorted_levels, colors):
    z_score = ci_factors[name]
    lower_bound = y_pred - z_score * y_std
    upper_bound = y_pred + z_score * y_std

    # Plot the confidence region (fill_between)
    plt.fill_between(X_plot.flatten(), lower_bound, upper_bound,
                     alpha=0.6, color=color, label=f'{name} Confidence Interval')

plt.title('Gaussian Process Regression: Effect of Confidence Interval Level')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='upper right')
plt.grid(True, linestyle=':', alpha=0.6)
plt.show() # In a local script, this would show the plot.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2781517558.py in <cell line: 0>()
#      20 plt.figure(figsize=(10, 6))
#      21 plt.scatter(x, y, color='red', marker='x', label='Training Data')
# ---> 22 plt.plot(x_test, y_mean, color='black', label='GP Mean Prediction')
#      23
#      24 colors = ['#C8E6C9', '#A5D6A7', '#81C784'] # Light to Dark Green
#
# NameError: name 'y_mean' is not defined

# %% [markdown]
# Change the `length_scale` and observe the changes in the plot.
#
# - Change the `kernel` to `Matern` and `RationalQuadratic` and observe the changes in the plot.
#
# - Change the confidence intervals as follows and observe the plots:
#
#   a. 68% confidence interval
#
#   b. 90% confidence interval
#
#   c. 99% confidence interval
